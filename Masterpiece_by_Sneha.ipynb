# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('VacantSitesSoldByURA.xlsx', na_values='na')
data
# Out:
#     date_of_launch date_of_tender_closing date_of_award  \
# 0       2016-04-28             2016-06-28    2016-07-01
# 1       2016-03-30             2016-05-24    2016-05-30
# 2       2016-02-25             2016-04-07    2016-04-13
# 3       2016-01-20             2016-02-23    2016-02-26
# 4       2015-11-26             2016-01-14    2016-01-18
# ..             ...                    ...           ...
# 335     1992-11-12             1993-01-07    1993-03-02
# 336     1992-11-12             1993-01-07    1993-03-02
# 337     1992-11-12             1993-01-07    1993-03-02
# 338     1992-08-31             1992-11-24    1993-02-15
# 339     1992-08-31             1992-11-24    1993-02-15
#
#                                          location  \
# 0                                    Martin Place
# 1                       Bukit Batok West Avenue 6
# 2                                    Jalan Kandis
# 3    New Upper Changi Road / Bedok South Avenue 3
# ...

# %%
data.dtypes
# Out:
# date_of_launch              datetime64[ns]
# date_of_tender_closing      datetime64[ns]
# date_of_award               datetime64[ns]
# location                            object
# type_of_devt_allowed                object
# lease                                int64
# type_of_devt_code                   object
# site_area                          float64
# gross_plot_ratio                   float64
# gross_floor_area                   float64
# no_of_bids                           int64
# successful_tenderer_name            object
# successful_tender_price            float64
# psm_per_gpr_or_gfa                 float64
# planning_area                       object
# dtype: object

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(data.corr(), xticklabels=data.corr().columns, yticklabels=data.corr().columns, cmap='Blues', center=0, annot=True)

# Decorations
plt.title('Correlation Matrix', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# /var/folders/sp/s1wtlvgd02jfbd812c313g3w0000gn/T/ipykernel_43621/3679883068.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), xticklabels=data.corr().columns, yticklabels=data.corr().columns, cmap='Blues', center=0, annot=True)
