# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_counts
# Out:
#     no_of_bids           type_of_devt_code  counts
# 0            1  Commercial and Residential       1
# 1            1                       Hotel       1
# 2            1                  Industrial       6
# 3            1                      Office       1
# 4            1                      Others       1
# ..         ...                         ...     ...
# 85          16    Residential (Non-Landed)       3
# 86          17    Residential (Non-Landed)       1
# 87          18                  Industrial       2
# 88          18    Residential (Non-Landed)       3
# 89          23    Residential (Non-Landed)       1
#
# [90 rows x 3 columns]

# %%
plt.style.use('default')

# %%
# Import Data
df_counts = df.groupby(['no_of_bids', 'type_of_devt_code']).size().reset_index(name='counts')

# Draw Stripplot
fig, ax = plt.subplots(figsize=(10,5), dpi= 80)    
sns.stripplot(data = df_counts, x ='type_of_devt_code', y = 'no_of_bids', hue = 'counts', ax=ax)

# Decorations
plt.title('Counts Plot - Size of circle is bigger as more points overlap', fontsize=22)
plt.xticks(rotation = 90)
plt.show()

# %%
# Import Data
df = pd.read_csv("VacantSitesSoldByURA.csv")
df_counts = df.groupby(['type_of_devt_code', 'no_of_bids']).size().reset_index(name='counts')

# Draw Stripplot
fig, ax = plt.subplots(figsize=(16,10), dpi= 80)    
sns.stripplot(df_counts.type_of_devt_code, df_counts.no_of_bids, size=df_counts.counts*2, ax=ax)

# Decorations
plt.title('Counts Plot - Size of circle is bigger as more points overlap', fontsize=22)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       5 # Draw Stripplot
#       6 fig, ax = plt.subplots(figsize=(16,10), dpi= 80)
# ----> 7 sns.stripplot(df_counts.type_of_devt_code, df_counts.no_of_bids, size=df_counts.counts*2, ax=ax, native_scale = True)
#       9 # Decorations
#      10 plt.title('Counts Plot - Size of circle is bigger as more points overlap', fontsize=22)
#
# TypeError: stripplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 3 keyword-only arguments) were given

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("VacantSitesSoldByURA.csv")
df_counts = df.groupby(['type_of_devt_code', 'no_of_bids']).size().reset_index(name='counts')


# Sample frequency data (you should replace this with your own data)
frequencies = df.groupby(['no_of_bids', 'type_of_devt_code']).size().reset_index(name='counts')

# Scale the frequencies to determine circle sizes
min_size = 10
max_size = 100
scaled_sizes = [min_size + (max_size - min_size) * (freq - min(frequencies)) / (max(frequencies) - min(frequencies)) for freq in frequencies]

# Define circle coordinates
x_coordinates = 'type_of_devt_code'
y_coordinates = 'no_of_bids'

# Create a scatter plot with circles
plt.figure(figsize=(8, 4))
plt.scatter(x_coordinates, y_coordinates, s=scaled_sizes, c='blue', alpha=0.7)
plt.title("Circles with Sizes Based on Frequency")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


for i, freq in enumerate(frequencies):
    plt.annotate(f"Freq: {freq}", (x_coordinates[i], y_coordinates[i]), ha='center', va='center')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      14 min_size = 10
#      15 max_size = 100
# ---> 16 scaled_sizes = [min_size + (max_size - min_size) * (freq - min(frequencies)) / (max(frequencies) - min(frequencies)) for freq in frequencies]
#      18 # Define circle coordinates
#      19 x_coordinates = 'type_of_devt_code'
#
# Cell In[4], line 16, in <listcomp>(.0)
#      14 min_size = 10
#      15 max_size = 100
# ---> 16 scaled_sizes = [min_size + (max_size - min_size) * (freq - min(frequencies)) / (max(frequencies) - min(frequencies)) for freq in frequencies]
#      18 # Define circle coordinates
#      19 x_coordinates = 'type_of_devt_code'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# Import Data
df_counts = df.groupby(['no_of_bids', 'type_of_devt_code']).size().reset_index(name='counts')

# Sort the data by 'type_of_devt_code' and 'no_of_bids'
df_counts = df_counts.sort_values(by=['type_of_devt_code', 'no_of_bids'])

# Draw Stripplot
fig, ax = plt.subplots(figsize=(10, 5), dpi=80)    
sns.stripplot(data=df_counts, x='type_of_devt_code', y='no_of_bids', hue='counts', ax=ax)

# Decorations
plt.title('Counts Plot - Size of circle is bigger as more points overlap', fontsize=22)
plt.xticks(rotation=90)
plt.show()

# %%
# Import Data
df_counts = df.groupby(['no_of_bids', 'type_of_devt_code']).size().reset_index(name='counts')

# Create a scatter plot with larger circles based on 'counts'
fig, ax = plt.subplots(figsize=(10, 5), dpi=80)
scatter = ax.scatter(df_counts['type_of_devt_code'], df_counts['no_of_bids'], s=df_counts['counts'] * 10, c=df_counts['counts'], cmap='viridis', alpha=0.5)

# Add a colorbar for the size of circles
cbar = plt.colorbar(scatter)
cbar.set_label('Counts')

# Decorations
plt.title('Type of Development Code by Number of Bids', fontsize=18)
plt.xlabel('Type of Development Code')
plt.ylabel('Number of Bids')
plt.xticks(rotation=90)

plt.show()
